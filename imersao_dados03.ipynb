# %% [markdown]
# <a href="https://colab.research.google.com/github/TheLima713/imersao_dados/blob/main/imersao_dados03.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # aula_dados_01

# %%
import pandas as pd
url_dados = 'https://github.com/alura-cursos/imersaodados3/blob/main/dados/dados_experimentos.zip?raw=true'
dados = pd.read_csv(url_dados, compression='zip')
dados
# Out:
#                  id    tratamento  tempo dose  ...    c-96    c-97    c-98    c-99
# 0      id_000644bb2     com_droga     24   D1  ... -0.3981  0.2139  0.3801  0.4176
# 1      id_000779bfc     com_droga     72   D1  ...  0.1522  0.1241  0.6077  0.7371
# 2      id_000a6266a     com_droga     48   D1  ... -0.6417 -0.2187 -1.4080  0.6931
# 3      id_0015fd391     com_droga     48   D1  ... -1.6210 -0.8784 -0.3876 -0.8154
# 4      id_001626bd3     com_droga     72   D2  ...  0.1094  0.2885 -0.3786  0.7125
# ...             ...           ...    ...  ...  ...     ...     ...     ...     ...
# 23809  id_fffb1ceed     com_droga     24   D2  ...  0.0631  0.9171  0.5258  0.4680
# 23810  id_fffb70c0c     com_droga     24   D2  ... -0.2084 -0.1224 -0.2715  0.3689
# 23811  id_fffc1c3f4  com_controle     48   D2  ...  0.2256  0.7592  0.6656  0.3808
# 23812  id_fffcb9e7c     com_droga     24   D1  ...  0.1732  0.7015 -0.6290  0.0740
# ...

# %%
dados.head()
# Out:
#              id tratamento  tempo dose  ...    c-96    c-97    c-98    c-99
# 0  id_000644bb2  com_droga     24   D1  ... -0.3981  0.2139  0.3801  0.4176
# 1  id_000779bfc  com_droga     72   D1  ...  0.1522  0.1241  0.6077  0.7371
# 2  id_000a6266a  com_droga     48   D1  ... -0.6417 -0.2187 -1.4080  0.6931
# 3  id_0015fd391  com_droga     48   D1  ... -1.6210 -0.8784 -0.3876 -0.8154
# 4  id_001626bd3  com_droga     72   D2  ...  0.1094  0.2885 -0.3786  0.7125
#
# [5 rows x 877 columns]

# %%
dados.shape
# Out:
# (23814, 877)

# %%
dados['tratamento']
# Out:
# 0           com_droga
# 1           com_droga
# 2           com_droga
# 3           com_droga
# 4           com_droga
#              ...
# 23809       com_droga
# 23810       com_droga
# 23811    com_controle
# 23812       com_droga
# 23813       com_droga
# Name: tratamento, Length: 23814, dtype: object

# %%
dados['tratamento'].unique()
# Out:
# array(['com_droga', 'com_controle'], dtype=object)

# %%
dados['tempo'].unique()
# Out:
# array([24, 72, 48])

# %%
dados['dose'].unique()
# Out:
# array(['D1', 'D2'], dtype=object)

# %%
dados['droga'].unique()
# Out:
# array(['b68db1d53', 'df89a8e5a', '18bb41b2c', ..., '573c787a2',
#        'b2fe3eca7', 'dd4a96d16'], dtype=object)

# %%
dados['g-0'].unique()
# Out:
# array([ 1.062 ,  0.0743,  0.628 , ...,  0.3942,  0.666 , -0.8598])

# %%
dados['tratamento'].value_counts()
# Out:
# com_droga       21948
# com_controle     1866
# Name: tratamento, dtype: int64

# %%
dados['dose'].value_counts()
# Out:
# D1    12147
# D2    11667
# Name: dose, dtype: int64

# %%
dados['tratamento'].value_counts(normalize = True)
# Out:
# com_droga       0.921643
# com_controle    0.078357
# Name: tratamento, dtype: float64

# %%
dados['dose'].value_counts(normalize = True)
# Out:
# D1    0.510078
# D2    0.489922
# Name: dose, dtype: float64

# %%
pie_dados = dados['tratamento'].value_counts().plot.pie(labels = ['Droga','Controle'])
pie_dados.set_title('Tortamento')
pie_dados.set_ylabel('')
pie_dados

# %%
dados['tempo'].value_counts().plot.pie()

# %%
dados['tempo'].value_counts().plot.bar()

# %%
dados_filtrados = dados[dados['g-0'] > 0]
dados_filtrados.head()
# Out:
#              id tratamento  tempo dose  ...    c-96    c-97    c-98    c-99
# 0  id_000644bb2  com_droga     24   D1  ... -0.3981  0.2139  0.3801  0.4176
# 1  id_000779bfc  com_droga     72   D1  ...  0.1522  0.1241  0.6077  0.7371
# 2  id_000a6266a  com_droga     48   D1  ... -0.6417 -0.2187 -1.4080  0.6931
# 6  id_001bd861f  com_droga     24   D2  ...  2.4670  0.0357  0.1351 -0.3179
# 7  id_0020d0484  com_droga     48   D1  ...  0.6633  0.4562 -0.9622  0.0260
#
# [5 rows x 877 columns]

# %% [markdown]
# # desafios_dados_01
# 1.   Por que em tratamento, droga>controle?
# 2.   Plotar as últimas 5 linhas da tabela
# 3.   Qual a proporção dentro de tratamento?
# 4.   Quantas drogas foram documentadas no experimento?
# 5.   Método Query da Documentação Pandas
# 6.   Dar Título aos Gráficos
# 7.   Renomear colunas sem hífen
# 8.   Resumir o aprendizado

# %%
#desafio_dados01

#desafio_dados02
# dados.tail()

#desafio_dados03
# tratamento = dados['tratamento'].value_counts()
# tratamento[0]/tratamento[1]

#desafio_dados04
# len(dados['droga'].value_counts())

#desafio_dados05
# dados.columns = dados.columns.str.replace('-', '')
# dados.query('g0 > 1')

#desafio_dados06
# pie_dados = dados['tratamento'].value_counts().plot.pie(labels = ['Droga','Controle'])
# pie_dados.set_title('Tortamento')
# pie_dados.set_ylabel('')
# pie_dados

#desafio_dados07
# dados.rename(columns={'g-0':'g0'})
# ou
# dados.columns = dados.columns.str.replace('-', '')
# dados.head()

#desafio_dados08
# import pandas as pd
# data = pd.read_csv('https://github.com/alura-cursos/imersaodados3/blob/main/dados/dados_experimentos.zip?raw=true', compression='zip')
# data.shape
# data.head()
# data.tail()
# data['tempo']
# data['tempo'].unique()
# data['tempo'].value_counts()
# data_bar = data['tempo'].value_counts(normalize=True).plot.bar()
# data_bar.set_title('Tempo')
# data.query('tempo>24')
# data.columns = data.columns.str.replace('-','_')
# data

# %% [markdown]
# # aula_dados_02

# %%
mapa = {'droga':'composto'}
dados.rename(columns=mapa,inplace=True)

# %%
cod_compostos = dados['composto'].value_counts().index[:5]

# %%
cod_compostos
# Out:
# Index(['cacb2b860', '87d714366', '9f80f3f77', '8b87a7a83', '5628cb3ee'], dtype='object')

# %%
dados.query('composto in @cod_compostos')
# Out:
#                  id    tratamento  tempo dose  ...    c-96    c-97    c-98    c-99
# 7      id_0020d0484     com_droga     48   D1  ...  0.6633  0.4562 -0.9622  0.0260
# 16     id_002fb9c19     com_droga     48   D1  ... -9.9840 -9.9840 -9.9840 -6.7840
# 25     id_0054388ec  com_controle     48   D1  ...  0.8837  0.5534  0.8976  1.0050
# 38     id_0079af0fb  com_controle     24   D1  ...  0.2187  0.0737  0.6498 -1.4820
# 40     id_007bfbb91  com_controle     24   D2  ... -0.5751  0.3362  0.8543  0.9180
# ...             ...           ...    ...  ...  ...     ...     ...     ...     ...
# 23793  id_ffd26f361  com_controle     48   D2  ...  0.8813  0.7757 -0.5272  0.7082
# 23802  id_fff3976bd     com_droga     24   D1  ... -8.4480 -4.4550 -5.7930 -3.7000
# 23805  id_fff6df1c5     com_droga     48   D2  ...  0.1516  0.4503 -0.6312 -0.8302
# 23811  id_fffc1c3f4  com_controle     48   D2  ...  0.2256  0.7592  0.6656  0.3808
# ...

# %%
import seaborn as sns
import matplotlib.pyplot as plt
sns.set()
plt.figure(figsize=(8,6))
ax = sns.countplot(x = 'composto',data=dados.query('composto in @cod_compostos'))
ax.set_title('Top 5 Compostos')
plt.show()

# %%
len(dados['g-0'].unique())
dados['g-0'].min()
dados['g-0'].max()
# Out:
# 10.0

# %%
dados['g-0'].hist(bins=100)

# %%
dados['g-19'].hist(bins=100)

# %%
dados.describe()
# Out:
#               tempo           g-0  ...          c-98          c-99
# count  23814.000000  23814.000000  ...  23814.000000  23814.000000
# mean      48.020156      0.248366  ...     -0.470252     -0.301505
# std       19.402807      1.393399  ...      1.834828      1.407918
# min       24.000000     -5.513000  ...    -10.000000    -10.000000
# 25%       24.000000     -0.473075  ...     -0.592600     -0.562900
# 50%       48.000000     -0.008850  ...      0.014000     -0.019500
# 75%       72.000000      0.525700  ...      0.461275      0.438650
# max       72.000000     10.000000  ...      3.111000      3.805000
#
# [8 rows x 873 columns]

# %%
dados[['g-0','g-2']].describe()
# Out:
#                 g-0           g-2
# count  23814.000000  23814.000000
# mean       0.248366      0.152253
# std        1.393399      1.035731
# min       -5.513000     -9.104000
# 25%       -0.473075     -0.437750
# 50%       -0.008850      0.075200
# 75%        0.525700      0.663925
# max       10.000000      8.257000

# %%
dados.loc[0:,'g-0':'g-771'].describe()
# Out:
#                 g-0           g-1  ...         g-770         g-771
# count  23814.000000  23814.000000  ...  23814.000000  23814.000000
# mean       0.248366     -0.095684  ...     -0.219210      0.101524
# std        1.393399      0.812363  ...      1.326193      1.417674
# min       -5.513000     -5.737000  ...    -10.000000    -10.000000
# 25%       -0.473075     -0.562200  ...     -0.554400     -0.523800
# 50%       -0.008850     -0.046600  ...      0.028700     -0.006500
# 75%        0.525700      0.403075  ...      0.496400      0.536950
# max       10.000000      5.039000  ...     10.000000     10.000000
#
# [8 rows x 772 columns]

# %%
dados.loc[0:,'g-0':'g-771'].describe().T['mean'].hist(bins=100)

# %%
dados.loc[0:,'g-0':'g-771'].describe().T['min'].hist(bins=100)
dados.loc[0:,'g-0':'g-771'].describe().T['max'].hist(bins=100)
dados.loc[0:,'c-0':'c-99'].describe().T['mean'].hist(bins=50)

# %%
#plt.figure(figsize=(10,6))
#sns.boxplot(x = 'g-0', data=dados)
#plt.figure(figsize=(10,6))
#sns.boxplot(y = 'g-0',x='tratamento', data=dados)

# %% [markdown]
# # desafio_dados_02
# 1. Ordenar o gráfico countplot
# 2. Como alterar os labels do gráfico
# 3. Ordenar o gráfico de Maior para Menor
# 4. Plotar histograma dos dados
# 5. Plotar histogramas com seaborn estudando estatísticas do .describe()
# 6. Refletir sobre a manipulação da visualização dos gráficos
# 7. Resumo da aula

# %%
#desafio_dados01

#desafio_dados02
# ... .plot.pie(labels = ['A','B'])
#desafio_dados03
# dados.loc[0:,'g-0':'g-771'].describe()
# sns.displot(data=dados.loc[0:,'g-0':'g-771'].describe())
#desafio_dados04
# Feito em aula
#desafio_dados05
# plt.figure(figsize=(12,6))
# dados.loc[0:,'g-0':'g-771'].describe().T['std'].hist(bins=100)
#desafio_dados06
# Importante haver espaçamento entre títulos, cores para destacar, e simplicidade na visualização
#desafio_dados07
# 
# dados.rename(columns=mapa,inplace=True)
# cod_compostos = dados['composto'].value_counts().index[:5]
# sns.set()
# plt.figure(figsize=(8,6))
# ax.set_title('Top 5 Compostos')
# plt.show()
# dados['g-0'].min()
# dados['g-0'].max()
# dados.loc[0:,'g-0':'g-771'].describe().T['mean'].hist(bins=100)
# sns.boxplot(x = 'g-0', data=dados)

# %% [markdown]
# # aula_dados_03

# %% [markdown]
# # desafios_dados_03
# 1. Tabela de frequência com groupby()
# 2. Normalizar o crosstab pela coluna
# 3. Explorar outros agregadores
# 4. Explorar o melt()
# 5. Calcular e analisar a correlação entre 'g' e 'c'
# 6. Estudar o código do heatmap e mask
# 7. Resumo da aula

# %%
#desafio_dados_01
# dados.groupby(['dose','tempo']).mean()

#desafio_dados_02
# pd.crosstab([dados['tratamento'],dados['tempo']],dados['dose'],values=dados['g-0'], normalize='columns', aggfunc='mean')

#desafio_dados_03
# pd.crosstab([dados['tratamento'],dados['tempo']],dados['dose'],values=dados['g-0'], normalize='columns', aggfunc='max')

#desafio_dados_04
# dados.melt(id_vars=['tempo'],value_vars=['dose','tratamento'])

#desafio_dados_05
# fail...
# corr = dados.loc[:,'g-0':'c-99'].corr()
# tri_mask = np.triu(np.ones_like(corr, dtype=bool))
# f, ax = plt.subplots(figsize=(14,10))
# col_map = sns.diverging_palette(300,150,s=50,l=50,as_cmap=True)
# sns.heatmap(corr, mask=tri_mask, cmap=col_map, )

#desafio_dados_06
# sns.heatmap(
    # data=dados,
    # mask=mascara,
    # cmap=mapa_de_cores,
    # center=iluminação_do_meio_do_espectro,
    # square=formato_das_celulas,
    # linewidths=linha_das_divisoes_das_celulas,
    # cbar_kws=key_word_arguments_for_bars)
    
#desafio_dados_07
#pd.crosstab([dados['tratamento'],dados['tempo']],dados['dose'],values=dados['g-0'], aggfunc='mean')
#scatterplot
#correlações
#lmplot e linha com kws, col e row
#plotar heatmap
# Out:
#        tempo    variable         value
# 0         24        dose            D1
# 1         72        dose            D1
# 2         48        dose            D1
# 3         48        dose            D1
# 4         72        dose            D2
# ...      ...         ...           ...
# 47623     24  tratamento     com_droga
# 47624     24  tratamento     com_droga
# 47625     48  tratamento  com_controle
# 47626     24  tratamento     com_droga
# 47627     72  tratamento     com_droga
#
# [47628 rows x 3 columns]

# %%
#pd.crosstab(dados['dose'],dados['tempo'])
#pd.crosstab([dados['dose'],dados['tempo']],dados['tratamento'])
#pd.crosstab([dados['dose'],dados['tempo']],dados['tratamento'],normalize = 'index')
pd.crosstab([dados['tratamento'],dados['tempo']],dados['dose'],values=dados['g-0'], normalize = 'columns', aggfunc='mean')
# Out:
# dose                      D1        D2
# tratamento   tempo
# com_controle 24    -0.634301  0.015877
#              48    -0.309323  0.019449
#              72    -0.743925  0.103713
# com_droga    24     0.927151  0.170153
#              48     1.039201  0.316646
#              72     0.721197  0.374163

# %%
#sns.scatterplot(x='g-0',y='g-3',data=dados)
#sns.scatterplot(x='g-0',y='g-8',data=dados)
#sns.lmplot(x='g-0',y='g-8',data=dados, line_kws={'color':'orange'})
sns.lmplot(x='g-0',y='g-8',data=dados, line_kws={'color':'orange'}, row='tratamento', col='tempo')

# %%
corr = dados.loc[:,'g-0':'c-99'].corr()
tri_mask = np.triu(np.ones_like(corr, dtype=bool))
f, ax = plt.subplots(figsize=(14,10))
col_map = sns.diverging_palette(300,150,s=50,l=50,as_cmap=True)
sns.heatmap(corr, mask=tri_mask, cmap=col_map, )
#
#corr = dados.loc[:,].corr()
#tri_mask = np.triu(np.ones_like(corr, dtype=bool))
#f, ax = plt.subplots(figsize=(10,8))
#col_map = sns.diverging_palette(300,200,s=50,l=50,as_cmap=True)
#sns.heatmap(corr, mask=tri_mask, cmap=col_map, )

# %%
import numpy as np
sns.set_theme()
# Compute the correlation matrix
corr = dados.loc[:,'g-0':'g-50'].corr()

# Generate a mask for the upper triangle
mask = np.triu(np.ones_like(corr, dtype=bool))

# Set up the matplotlib figure
f, ax = plt.subplots(figsize=(11, 9))

# Generate a custom diverging colormap
cmap = sns.diverging_palette(250, 10,s=100,l=50, as_cmap=True)

# Draw the heatmap with the mask and correct aspect ratio
sns.heatmap(corr, mask=mask, cmap=cmap, center=0,
            square=True, linewidths=.5, cbar_kws={"shrink": .5})

# %%
corr= dados.loc[:,'c-0':'c-50'].corr()

# Generate a mask for the upper triangle
mask = np.triu(np.ones_like(corr, dtype=bool))

# Set up the matplotlib figure
f, ax = plt.subplots(figsize=(11, 9))

# Generate a custom diverging colormap
cmap = sns.diverging_palette(250, 10,s=70,l=50, as_cmap=True)

# Draw the heatmap with the mask and correct aspect ratio
sns.heatmap(corr, mask=mask, cmap=cmap, center=0,
            square=True, linewidths=.5, cbar_kws={"shrink": .5})
